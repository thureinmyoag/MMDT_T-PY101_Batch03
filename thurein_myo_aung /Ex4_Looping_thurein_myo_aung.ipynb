# %% [markdown]
# <a href="https://colab.research.google.com/github/thureinmyoag/MMDT_T-PY101_Batch03/blob/main/thurein_myo_aung%20/Ex4_Looping_thurein_myo_aung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
st = input("Give me a string: ")
i = 0
while i < len(st):
  print(st[i])
  i = i + 1
# Out:
# Give me a string: hello world
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
wt_kg = float(input("Enter weight in kilograms: "))
while wt_kg < 0:
  print("Your entry is invalid. Please re-enter the weight")
  wt_kg = float(input("Enter weight in kilograms: "))
wt_pd = round(wt_kg * 2.20462,4)
print(f"Weight in pounds: {wt_pd}")
# Out:
# Enter weight in kilograms: -1
# Your entry is invalid. Please re-enter the weight
# Enter weight in kilograms: 22
# Weight in pounds: 48.5016

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
score = int(input("Enter any number of test scores: "))
counter = 0
counter_A = 0
total = 0
while score > 0:
  if score >= 90:
    counter_A = counter_A + 1
    total = total + score
    counter = counter + 1
    score = int(input("Enter any number of test scores: "))
  else:
    total = total + score
    counter = counter + 1
    score = int(input("Enter any number of test scores: "))

    # score_add = score_add + score
average = total//counter

print(f"No of 'A's grade {counter_A}")
print(f"Average {average}")
# Out:
# Enter any number of test scores50
# Enter any number of test scores100
# Enter any number of test scores90
# Enter any number of test scores80
# Enter any number of test scores-1
# No of 'A's grade 2
# Average 80

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
st = input("Give me a string: ")
lt = input("Give me a letter: ")
enumerated_st = enumerate(st)
is_found = False
for index,char in enumerated_st:
  if char == lt:
    print(index)
    is_found = True
    break
if is_found == False:
  print("The string does not contain the letter")
# Out:
# Give me a string: hireinfi
# Give me a letter: z
# The string does not contain the letter

# %% [markdown]
# nEx 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
l = [1,1,1,1,0,1,0]
enumerate_list = enumerate(l)
has_zero = False
for index,val in enumerate_list:
  if val == 0:
    l[index] = 1
    has_zero = True
    print(l)
    break
if has_zero == False:
  print("There is no zero value")
# Out:
# [1, 1, 1, 1, 1, 1, 0]
